# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException, ElementNotInteractableException

#Importing requests
import requests

# importing regex
import re

# %% [markdown]
# Q1-Scrape the details of most viewed videos on YouTube from Wikipedia:
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(4)

# Opening the url
url = "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
driver.get(url)

# %%
#scraping names of the video
Rank=[]
try:
    rank_tag=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[1]")
    for i in rank_tag:
        Rank.append(i.text)
except NoSuchElementException:#handling no such element exception
    Rank.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    Rank.append('No details available')

# %%
#scraping names of the video
name=[]
try:
    names=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[2]")
    for i in names:
        name.append(i.text)
except NoSuchElementException:#handling no such element exception
    name.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    name.append('No details available')

# %%
#scraping artist
Artist=[]
try:
    artist=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[3]")
    for i in artist:
        Artist.append(i.text)
except NoSuchElementException:#handling no such element exception
    Artist.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    Artist.append('No details available')

# %%
#scraping views
views=[]
try:
    v_tag=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]")
    for i in v_tag:
        views.append(i.text)
except NoSuchElementException:#handling no such element exception
    views.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    views.append('No details available')

# %%
##scraping upload date
upload_date=[]
try:
    date=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[5]")
    for i in date:
        upload_date.append(i.text)
except NoSuchElementException:#handling no such element exception
    upload_date.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    upload_date.append('No details available')

# %%
time.sleep(2)    
# Make dataframe
df = pd.DataFrame({'Rank':Rank,'Name':name,'Artist':Artist,'View':views,'Upload Date':upload_date })
df
# Out:
#    Rank                                             Name  \
# 0    1.                           "Baby Shark Dance"[22]
# 1    2.                                  "Despacito"[24]
# 2    3.                       "Johny Johny Yes Papa"[25]
# 3    4.                               "Shape of You"[26]
# 4    5.                              "See You Again"[27]
# 5    6.   "Masha and the Bear – Recipe for Disaster"[30]
# 6    7.                                  "Bath Song"[31]
# 7    8.  "Learning Colors – Colorful Eggs on a Farm"[32]
# 8    9.                                "Uptown Funk"[33]
# 9   10.                              "Gangnam Style"[34]
# 10  11.                "Phonics Song with Two Words"[36]
# 11  12.                                      "Sugar"[37]
# 12  13.                             "Dame Tu Cosita"[38]
# 13  14.                                      "Sorry"[39]
# 14  15.                                       "Roar"[40]
# ...

# %% [markdown]
# Q.2 Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/. You need to find following details:A) Match title (I.e. 1st ODI) B) Series C) Place D) Date E) Time

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(4)

url = "https://www.bcci.tv/"
driver.get(url)
time.sleep(3)

# %%
#going to international fixtures page
fixtures=driver.find_element_by_xpath("//div[@class='navigation__drop-down drop-down drop-down--reveal-on-hover']/div/ul/li/a")
try:
    fixtures.click()
except ElementNotInteractableException:
    driver.get(fixtures.get_attribute('href'))

# %%
Match_title=[]
#scraping match title
M_tag=driver.find_elements_by_xpath("//div[@class='fixture__format-strip']//span[1]")
for i in M_tag:
    if i.text is None :
        Match_title.append("--") 
    else:
        Match_title.append(i.text)

# %%
series_title=[]
#scraping series title
S_tag=driver.find_elements_by_xpath("//div[@class='fixture__format-strip']//span[2]")
for i in S_tag:
    if i.text is None :
        series_title.append("--") 
    else:
        series_title.append(i.text)

# %%
place=[]
#scraping place
p_tag=driver.find_elements_by_xpath("//p[@class='fixture__additional-info']//span")
for i in p_tag:
    if i.text is None :
        place.append("--") 
    else:
        place.append(i.text)

# %%
date=[]
#scraping date
d_tag=driver.find_elements_by_xpath("//span[@class='fixture__datetime tablet-only']")
for i in d_tag:
    if i.text is None :
        date.append("--") 
    else:
        date.append(i.text)

# %%
# Make dataframe
df = pd.DataFrame({'Match title':Match_title,'Series':series_title,'Place':place,'Date and Time':date })
df
# Out:
#   Match title                Series                     Place  \
# 0        TEST  ENGLAND V INDIA 2021            Lord's, London
# 1        TEST  ENGLAND V INDIA 2021         Headingley, Leeds
# 2        TEST  ENGLAND V INDIA 2021          The Oval, London
# 3        TEST  ENGLAND V INDIA 2021  Old Trafford, Manchester
#
#                       Date and Time
# 0    Thursday 12th August 15:30 IST
# 1   Wednesday 25th August 15:30 IST
# 2  Thursday 2nd September 15:30 IST
# 3   Friday 10th September 15:30 IST

# %% [markdown]
# Q.3-Scrape the details of selenium exception from guru99.com.Url = https://www.guru99.com/
# You need to find following details:A) Name B) Description

# %%
# Activating the chrome browser
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(2)

# Opening the guru99.com
url = "https://www.guru99.com/"
driver.get(url)
time.sleep(2)

# %%
#clicking on selenium option under testing menu open its tutorial
selenium_link=driver.find_element_by_xpath("//li[@class='g-menu-item g-menu-item-type-component g-menu-item-121  ']/a")
try:
    selenium_link.click()
except ElementNotInteractableException:          #handling element not clickable exception
    driver.get(selenium_link.get_attribute('href'))
time.sleep(2)

#clicking on Selenium Exception Handling (Common Exceptions List) under Advance Webdriver Stuff!
exception_handle_link=driver.find_element_by_xpath("//a[@title='Selenium Exception Handling (Common Exceptions List)']")
try:
    exception_handle_link.click()
except ElementNotInteractableException:      #handling element not clickable exception
    driver.get(exception_handle_link.get_attribute('href'))              
time.sleep(2)

# %%
#scraping name
name=[]
try:
    N_tag=driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td[1]")
    for i in N_tag:
        name.append(i.text)
except NoSuchElementException:#handling no such element exception
    name.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    name.append('No details available')

# %%
#scraping description
description=[]
try:
    d_tag=driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td[2]")
    for i in d_tag:
        description.append(i.text)
except NoSuchElementException:#handling no such element exception
    description.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    description.append('No details available')

# %%
time.sleep(2)    
# Make dataframe
df = pd.DataFrame({'Name':name,'Description':description})
df
# Out:
#                                    Name  \
# 0                        Exception name
# 1            ElementNotVisibleException
# 2         ElementNotSelectableException
# 3                NoSuchElementException
# 4                  NoSuchFrameException
# 5               NoAlertPresentException
# 6                 NoSuchWindowException
# 7        StaleElementReferenceException
# 8              SessionNotFoundException
# 9                      TimeoutException
# 10                   WebDriverException
# 11            ConnectionClosedException
# 12     ElementClickInterceptedException
# 13      ElementNotInteractableException
# 14             ErrorInResponseException
# 15  ErrorHandler.UnknownServerException
# 16         ImeActivationFailedException
# 17             ImeNotAvailableException
# 18         InsecureCertificateException
# 19             InvalidArgumentException
# 20         InvalidCookieDomainException
# 21          InvalidCoordinatesException
# ...

# %% [markdown]
# Q.4-Scrape the details of State-wise GDP of India from statisticstime.com.Url = http://statisticstimes.com/
# You have to find following details:A) Rank B) State C) GSDP at current price (19-20) D) GSDP at current price (18-19)
# E) Share(18-19) F) GDP($ billion)

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(4)

url = "http://statisticstimes.com/economy/india/indian-states-gdp.php"
driver.get(url)
time.sleep(6)

# %%
rank=[]
try:
    r_tag=driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[1]")
    for i in r_tag:
        rank.append(i.text)
except NoSuchElementException:#handling no such element exception
    rank.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    rank.append('No details available')

# %%
state=[]
try:
    s_tag=driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[2]")
    for i in s_tag:
        state.append(i.text)
except NoSuchElementException:#handling no such element exception
    state.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    state.append('No details available')

# %%
GSDP1=[]
try:
    g_tag=driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[3]")
    for i in g_tag:
        GSDP1.append(i.text)
except NoSuchElementException:#handling no such element exception
    GSDP1.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    GSDP1.append('No details available')

# %%
GSDP2=[]
try:
    gg_tag=driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[4]")
    for i in gg_tag:
        GSDP2.append(i.text)
except NoSuchElementException:#handling no such element exception
    GSDP2.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    GSDP2.append('No details available')

# %%
share=[]
try:
    sh_tag=driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[5]")
    for i in sh_tag:
        share.append(i.text)
except NoSuchElementException:#handling no such element exception
    share.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    share.append('No details available')

# %%
GDP=[]
try:
    F_tag=driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[6]")
    for i in F_tag:
        GDP.append(i.text)
except NoSuchElementException:#handling no such element exception
    GDP.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    GDP.append('No details available')

# %%
time.sleep(2)    
# Make dataframe
df = pd.DataFrame({'Rank':rank,'State':state,'GSDP at current price (19-20)':GSDP1,'GSDP at current price (18-19)':GSDP2, 'Share(18-19)':share, 'GDP($ billion)':GDP})
df
# Out:
#    Rank                      State GSDP at current price (19-20)  \
# 0     1                Maharashtra                             -
# 1     2                 Tamil Nadu                     1,845,853
# 2     3              Uttar Pradesh                     1,687,818
# 3     4                    Gujarat                             -
# 4     5                  Karnataka                     1,631,977
# ..  ...                        ...                           ...
# 61   29                     Sikkim                        28,391
# 62   30                   Nagaland                             -
# 63   31          Arunachal Pradesh                             -
# 64   32                    Mizoram                        24,424
# 65   33  Andaman & Nicobar Islands                             -
#
#    GSDP at current price (18-19) Share(18-19) GDP($ billion)
# 0                      2,632,792       13.94%        399.921
# 1                      1,630,208        8.63%        247.629
# ...

# %% [markdown]
# Q.5-Scrape the details of trending repositories on Github.com.
# Url = https://github.com/ You have to find the following details: A) Repository title B) Repository description C) Contributors count D) Language used

# %%
# webdrive for chrome
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(4)
#getting url
url = "https://github.com/"
driver.get(url)
time.sleep(6)

# %%
#scraping Repository title
Name=[]
try:
    N_tag=driver.find_elements_by_xpath("//span[@class='text-normal']")
    for i in N_tag:
        Name.append(i.text)
except NoSuchElementException:#handling no such element exception
    Name.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    Name.append('No details available')

# %%
#scraping Repository description
desc=[]
try:
    d_tag=driver.find_elements_by_xpath("//p[@class='col-9 color-text-secondary my-1 pr-4']")
    for i in d_tag:
        desc.append(i.text)
except NoSuchElementException:#handling no such element exception
    desc.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    desc.append('No details available')

# %%
#scraping cont.count
count=[]
try:
    c_tag=driver.find_elements_by_xpath("//a[@class='Link--muted d-inline-block mr-3']")
    for i in c_tag:
        count.append(i.text)
except NoSuchElementException:#handling no such element exception
    count.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    count.append('No details available')

# %%
#scraping language
language=[]
try:
    lan_tag=driver.find_elements_by_xpath("//span[@class='d-inline-block ml-0 mr-3']")
    for i in lan_tag:
        language.append(i.text)
except NoSuchElementException:#handling no such element exception
    language.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    language.append('No details available')

# %%
# Make dataframe
df = pd.DataFrame({'Repository title':Name[:21],'Repository description':desc[:21],'Contributors count':count[:21],'Language used':language[:21]})
df
# Out:
#           Repository title                             Repository description  \
# 0              microsoft /                           Tool for parsing GC logs
# 1            willmcgugan /  Textual is a TUI (Text User Interface) framewo...
# 2           trufflesuite /  A tool for developing smart contracts. Crafted...
# 3              yifeikong /                                      技术面试最后反问面试官的话
# 4             codebasics /  Repository to store sample python programs for...
# 5                   expo /  An open-source platform for making universal n...
# 6            hora-search /  🚀 efficient approximate nearest neighbor searc...
# 7                  RPCS3 /                              PS3 emulator/debugger
# 8                sharkdp /  A simple, fast and user-friendly alternative t...
# 9             Snailclimb /  「Java学习+面试指南」一份涵盖大部分 Java 程序员所需要掌握的核心知识。准备 Jav...
# 10  TCM-Course-Resources /  Compilation of Resources from TCM's Practical ...
# ...

# %% [markdown]
# Q.6-Scrape the details of top 100 songs on billboard.com.Url = https://www.billboard.com/ You have to find the following details:A) Song name B) Artist name C) Last week rank D) Peak rank E) Weeks on board

# %%
# webdrive for chrome
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(4)
#getting url
url = "https://www.billboard.com"
driver.get(url)
time.sleep(6)

# %%
# clicking on hot 100
Hot_tag=driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/nav/ul/li[3]/a')
Hot_tag.click()

# %%
#scraping Last week rank
last_week=[]
try:
    L_tag=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']")
    for i in L_tag:
        last_week.append(i.text)
except NoSuchElementException:#handling no such element exception
    last_week.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    last_week.append('No details available')

# %%
name=[]
#scraping song name
try:
    n_tag=driver.find_elements_by_xpath("//span[@class='chart-element__information__song text--truncate color--primary']")
    for i in n_tag:
        name.append(i.text)
except NoSuchElementException:#handling no such element exception
    name.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    name.append('No details available')

# %%
artist=[]
#scraping artist name
try:
    a_tag=driver.find_elements_by_xpath("//span[@class='chart-element__information__artist text--truncate color--secondary']")
    for i in a_tag:
        artist.append(i.text)
except NoSuchElementException:#handling no such element exception
    artist.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    artist.append('No details available')

# %%
peak_rank=[]
#scraping peak rank
try:
    p_tag=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']")
    for i in p_tag:
        peak_rank.append(i.text)
except NoSuchElementException:#handling no such element exception
    peak_rank.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    peak_rank.append('No details available')

# %%
week=[]
#scraping weeks on board
try:
    w_tag=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--week']")
    for i in w_tag:
        week.append(i.text)
except NoSuchElementException:#handling no such element exception
    week.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    week.append('No details available')

# %%
time.sleep(2)    
# Make dataframe
df = pd.DataFrame({'song name':name,'Artist_name':artist,'Last week rank':last_week,'Peak rank':peak_rank,'Weeks on board':week})
df
# Out:
#           song name                                        Artist_name  \
# 0            Butter                                                BTS
# 1     Industry Baby                            Lil Nas X & Jack Harlow
# 2          Good 4 U                                     Olivia Rodrigo
# 3              Stay                      The Kid LAROI & Justin Bieber
# 4        Levitating                          Dua Lipa Featuring DaBaby
# ..              ...                                                ...
# 95     Minimum Wage                                      Blake Shelton
# 96          Working                                Tate McRae X Khalid
# 97      Holy Smokes                Trippie Redd Featuring Lil Uzi Vert
# 98        WUSYANAME  Tyler, The Creator Featuring YoungBoy Never Br...
# 99  Still Chose You                    The Kid LAROI Featuring Mustard
#
#    Last week rank Peak rank Weeks on board
# 0               1         1             10
# ...

# %% [markdown]
# Q.7-#Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:A) Name B) Designation C) Company D) Skills they hire for E) Location

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(4)

url = "https://www.naukri.com/data-science-recruiters"
driver.get(url)
time.sleep(6)

Recuirter_name=[]
#scraping Name
titles=driver.find_elements_by_xpath("//span[@class='fl ellipsis']")
titles
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="9b6269021a1bfe51f054d572f23c7d66", element="843404c5-7498-4a06-b4fc-f0b06148c7cd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9b6269021a1bfe51f054d572f23c7d66", element="a352d662-baea-4783-9d6e-9129c1ba8786")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9b6269021a1bfe51f054d572f23c7d66", element="da04ff2f-f340-4353-a6a6-dec1d8193f07")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9b6269021a1bfe51f054d572f23c7d66", element="32697177-c28d-47a6-90ff-ec6818a0bfb9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9b6269021a1bfe51f054d572f23c7d66", element="c086c818-cd03-4cdf-bfac-a31e95f47e9b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9b6269021a1bfe51f054d572f23c7d66", element="d84ee63a-fe15-46e3-bebc-ba51be8c347c")>,
# ...

# %%
for i in titles:
    if i.text is None :
        Recuirter_name.append("--") 
    else:
        Recuirter_name.append(i.text)

# %%
designation=[]
#scraping designation
designation_tag=driver.find_elements_by_xpath("//span[@class='ellipsis clr']")
for i in designation_tag:
    if i.text is None :
        designation.append("--") 
    else:
        designation.append(i.text)

# %%
Description=[]
#scraping description
Des_tag=driver.find_elements_by_xpath("//div[@class='hireSec highlightable']")
for i in Des_tag:
    if i.text is None :
        Description.append("--") 
    else:
        Description.append(i.text)

# %%
Location=[]
#scraping location
try:
    L_tag=driver.find_elements_by_xpath("//a[@class='ellipsis']//i")
    for i in L_tag:
        Location.append(i.text)
except NoSuchElementException:#handling no such element exception
    Location.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    Location.append('No details available')

# %%
company=[]
urls =[]
for i in driver.find_elements_by_xpath("//a[@class ='ellipsis']"):
    urls.append(i.get_attribute("href"))

for i in urls:
    driver.get(i)
    time.sleep(3)
#comapny title
    try:
        job=driver.find_element_by_xpath("//i[@class='cmpIcn']")
        company.append(job.text)
    except NoSuchElementException:
        company.append('-')

# %%
time.sleep(2)    
# Make dataframe
df = pd.DataFrame({'Recuirter_name':Recuirter_name[:50],'designation':designation[:50],'Description':Description[:50]})
df
# Out:
#                                    Recuirter_name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                 Priyanka Akiri
# 11                                Kalpana Dumpala
# 12                                        Mubarak
# 13                                 Kushal Rastogi
# 14                                    Ruchi Dhote
# 15                             Mahesh Babu Channa
# 16                                   Kapil Devang
# 17                                  Manisha Yadav
# ...

# %% [markdown]
# #Q.8-Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
# Activating the chrome browser
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(2)

#
url = "https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/"
driver.get(url)
time.sleep(2)

# %%
#scrapping book names
book_name=[]
try:
    names=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[2]")
    for i in names:
        book_name.append(i.text)
except NoSuchElementException:              #handling no such element exception
    book_name.append('No details available')

# %%
#scrapping author names
aurthor_name=[]
try:
    A_names=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[3]")
    for i in A_names:
        aurthor_name.append(i.text)
except NoSuchElementException:              #handling no such element exception
    aurthor_name.append('No details available')

# %%
#scrapping volume sold
Volume=[]
try:
    Vol=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[4]")
    for i in Vol:
        Volume.append(i.text)
except NoSuchElementException:              #handling no such element exception
    Volume.append('No details available')

# %%
#scrapping Publisher
publisher=[]
try:
    pub=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[5]")
    for i in pub:
        publisher.append(i.text)
except NoSuchElementException:              #handling no such element exception
    publisher.append('No details available')

# %%
#scrapping Genre
Genre=[]
try:
    Gen=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[6]")
    for i in Gen:
        Genre.append(i.text)
except NoSuchElementException:              #handling no such element exception
    Genre.append('No details available')

# %%
time.sleep(2)    
# Make dataframe
df = pd.DataFrame({'Book Name':book_name, 'Author Name':aurthor_name, 'Volume sold':Volume,'Publisher':publisher,'Genre':Genre})
df
# Out:
#                                             Book Name       Author Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume sold        Publisher                        Genre
# ...

# %% [markdown]
# #Q-9. Scrape the details most watched tv series of all time from imdb.com.
#  Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
# opening required Url
url = "https://www.imdb.com/list/ls095964455/"
driver.get(url)
time.sleep(2)

# %%
Name=[]
#scraping Name
N_tag=driver.find_elements_by_xpath("//h3[@class='lister-item-header']//a")
for i in N_tag:
    if i.text is None :
        Name.append("--") 
    else:
        Name.append(i.text)

# %%
year_span=[]
#scraping year_span
y_tag=driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']")
for i in y_tag:
    if i.text is None :
        year_span.append("--") 
    else:
        year_span.append(i.text)

# %%
Genre=[]
#scraping Genre
G_tag=driver.find_elements_by_xpath("//p[@class='text-muted text-small']//span[5]")
for i in G_tag:
    if i.text is None :
        Genre.append("--") 
    else:
        Genre.append(i.text)

# %%
Ratings=[]
#scraping ratings
R_tag=driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']//span[2]")
for i in R_tag:
    if i.text is None :
        Ratings.append("--") 
    else:
        Ratings.append(i.text)

# %%
Runtime=[]
#scraping runtime
r_tag=driver.find_elements_by_xpath("//p[@class='text-muted text-small']//span[3]")
for i in r_tag:
    if i.text is None :
        Runtime.append("--") 
    else:
        Runtime.append(i.text)

# %%
votes=[]
#scraping votes
v_tag=driver.find_elements_by_xpath("//p[@class='text-muted text-small']//span[2]")
for i in v_tag:
    if i.text is None :
        votes.append("--") 
    else:
        votes.append(i.text)

# %%
#scraping final-votes from scraped information
final_votes=[]
for i in range(1,len(votes),2):
    final_votes.append(votes[i])

# %%
time.sleep(2)    
# Make dataframe
IMdb = pd.DataFrame({'Name':Name,'year_span':year_span,'Genre':Genre,'Runtime':Runtime,'Ratings':Ratings,'votes':final_votes})
IMdb
# Out:
#                               Name    year_span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#     Runtime Ratings      votes
# 0    57 min     9.2  1,850,160
# ...

# %% [markdown]
# Q.10 Details of Datasets from UCI machine learning repositories.
#  Url = https://archive.ics.uci.edu/
#  You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the Show All Dataset page through code

# %%
# Activating the chrome browser
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(2)

# opening url
url = "https://archive.ics.uci.edu/ml/index.php"
driver.get(url)
time.sleep(2)

# %%
# loacting show all dataset
dataset=driver.find_element_by_xpath('/html/body/table[1]/tbody/tr/td[2]/span[2]/a/font/b')
dataset.click()

# %%
#scrapping datset name
Data=[]
try:
    data=driver.find_elements_by_xpath("/html/body/table/tbody/tr/td/table/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b/a")
    for i in data:
        Data.append(i.text)
except NoSuchElementException:              #handling no such element exception
    Data.append('No details available')

# %%
#scrapping Data type
data_type=[]
try:
    data=driver.find_elements_by_xpath("/html/body/table/tbody/tr/td/table/tbody/tr/td[2]/p")
    for i in data:
        data_type.append(i.text)
except NoSuchElementException:              #handling no such element exception
    data_type.append('No details available')

# %%
#scrapping default task
default=[]
try:
    dt=driver.find_elements_by_xpath("/html/body/table/tbody/tr/td/table/tbody/tr/td[3]/p")
    for i in dt:
        default.append(i.text)
except NoSuchElementException:              #handling no such element exception
    default.append('No details available')

# %%
#scrapping attribute type
att_type=[]
try:
    att=driver.find_elements_by_xpath("/html/body/table/tbody/tr/td/table/tbody/tr/td[4]/p")
    for i in att:
        att_type.append(i.text)
except NoSuchElementException:              #handling no such element exception
    att_type.append('No details available')

# %%
#scrapping instance
instance=[]
try:
    ins=driver.find_elements_by_xpath("/html/body/table/tbody/tr/td/table/tbody/tr/td[5]/p")
    for i in ins:
        instance.append(i.text)
except NoSuchElementException:              #handling no such element exception
    instance.append('No details available')

# %%
#scrapping attribute
attribute=[]
try:
    tag=driver.find_elements_by_xpath("/html/body/table/tbody/tr/td/table/tbody/tr/td[6]/p")
    for i in tag:
        attribute.append(i.text)
except NoSuchElementException:              #handling no such element exception
    attribute.append('No details available')

# %%
#scrapping year
year=[]
try:
    y_tag=driver.find_elements_by_xpath("/html/body/table/tbody/tr/td/table/tbody/tr/td[7]/p")
    for i in y_tag:
        year.append(i.text)
except NoSuchElementException:              #handling no such element exception
    year.append('No details available')

# %%
time.sleep(2)    
# Make dataframe
df = pd.DataFrame({'Dataset name':Data[:588],'Data type':data_type[:588],'Task':default[:588],'Attribute type':att_type[:588],'No of instances':instance[:588],'No of attribute':attribute[:588], 'Year Note':year[:588]})
df
# Out:
#                          Dataset name                   Data type  \
# 0                             Abalone       Table View  List View
# 1                               Adult                  Data Types
# 2                           Annealing               Multivariate
# 3        Anonymous Microsoft Web Data               Multivariate
# 4                          Arrhythmia               Multivariate
# ..                                ...                         ...
# 583  in-vehicle coupon recommendation  Multivariate, Time-Series
# 584               Gait Classification               Multivariate
# 585         Wikipedia Math Essentials               Multivariate
# 586         Wikipedia Math Essentials               Multivariate
# 587      Synchronous Machine Data Set                Time-Series
#
#                      Task               Attribute type No of instances  \
# 0            Default Task              Attribute Types     # Instances
# ...
